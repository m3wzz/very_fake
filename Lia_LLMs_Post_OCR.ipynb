# %% [markdown]
# <a href="https://colab.research.google.com/github/m3wzz/very_fake/blob/main/Lia_LLMs_Post_OCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Large Language Models and Post-OCR-Correction
#
#
# Created by Sarah Oberbichler [![ORCID](data:image/svg+xml;base64,...)](https://orcid.org/0000-0002-1031-2759)
#
# Post-OCR correction addresses errors introduced when optical character recognition (OCR) converts scanned images into digital text. Common errors include character substitutions (e.g., "rn" misread as "m"), deletions, and formatting issues caused by poor image quality, unusual fonts, or degraded historical documents. Correction techniques range from dictionary-based validation and language models that use context to identify mistakes, to modern machine learning approaches—particularly large language models (LLMs)—that can intelligently reconstruct intended meaning from garbled text. This correction step is essential for downstream applications like text mining, digital archiving, and information retrieval, as even small error rates can significantly impact analysis quality and user experience.

# %%
# !git clone https://github.com/soberbichler/NLP-Course4Humanities_2025.github.io.git
# Out:
# Cloning into 'NLP-Course4Humanities_2025.github.io'...
# remote: Enumerating objects: 1800, done.
# remote: Counting objects: 100% (178/178), done.
# remote: Compressing objects: 100% (154/154), done.
# remote: Total 1800 (delta 120), reused 23 (delta 23), pack-reused 1622 (from 2)
# Receiving objects: 100% (1800/1800), 109.70 MiB | 27.80 MiB/s, done.
# Resolving deltas: 100% (1039/1039), done.

# %%
import pandas as pd

# Replace 'your_excel_file.xlsx' with the actual path to your Excel file
df = pd.read_excel('/content/NLP-Course4Humanities_2025.github.io/datasets/lügenpresse_dataset (1).xlsx')

# Now you can work with the DataFrame 'df'
df.head()
# Out:
#                                              page_id  pagenumber  \
# 0  22IKTI2DCKL6UM6H62FNWHOG4SIHYRPY-ALTO2864623_D...           3
# 1  22O4KEI3WEZ27D2K65VLFDIONOJAZH5L-ALTO676714_DD...          10
# 2  233N6HVY2EZW3FQCMTO6HN3IXSJ2CIJA-ALTO5264456_D...           1
# 3  23D7JNHE332P6XGZZ4WW65TOCLBQDUBE-FILE_0001_DDB...           1
# 4  23ZT3TJSGVQDECCUS6SNUFPNCE5CEDUI-ALTO10636965_...           2
#
#                                          paper_title  \
# 0                    Mayener Volkszeitung. 1876-1919
# 1                            Der neue Tag. 1934-1944
# 2  Lippische Landes-Zeitung : ältestes und weitve...
# 3  Süddeutsche Zeitung : für deutsche Politik und...
# 4  Wittener Tageblatt : verbunden mit der Annener...
#
#                     provider_ddb_id  \
# 0  VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 1  VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 2  4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 3  VNHXUCEEKHOUSYH4NVOUBHJGSRMOGK7J
# 4  4EV676FQPACNVNHFEJHGKUY55BXC3QMB
#
#                                             provider     zdb_id  \
# 0  Universitäts- und Landesbibliothek der Rheinis...  2664084-3
# 1  Universitäts- und Landesbibliothek der Rheinis...  2927784-X
# 2  Westfälische Wilhelms-Universität Münster Univ...  2944740-9
# 3                  Württembergische Landesbibliothek  3135995-4
# 4  Westfälische Wilhelms-Universität Münster Univ...  3052283-3
#
#      publication_date                              place_of_distribution  \
# 0 1914-10-30 12:00:00                                          ['Mayen']
# 1 1938-02-26 12:00:00                                           ['Köln']
# 2 1881-06-20 12:00:00  ['Extertal', 'Horn-Bad Meinberg', 'Barntrup', ...
# 3 1915-02-19 12:00:00                                      ['Stuttgart']
# 4 1940-10-14 12:00:00                                         ['Witten']
#
#   language                             thumbnail  \
# 0  ['ger']  0fde6f1f-67cc-49a8-9c5a-b8f806e3410a
# 1  ['ger']  fb256fca-9747-4098-b1fc-a5d3b49d6ed7
# 2  ['ger']  151b36f5-1ce2-4676-9940-08260ced980a
# 3  ['ger']  2ea243ce-eb0c-4475-b64f-6ce176709aff
# 4  ['ger']  cf34ec30-f901-4dc5-b195-e577429c885f
#
#                                         pagefulltext  \
# 0  /data/altos/22/IK/22IKTI2DCKL6UM6H62FNWHOG4SIH...
# 1  /data/altos/22/O4/22O4KEI3WEZ27D2K65VLFDIONOJA...
# 2  /data/altos/23/3N/233N6HVY2EZW3FQCMTO6HN3IXSJ2...
# 3  /data/altos/23/D7/23D7JNHE332P6XGZZ4WW65TOCLBQ...
# 4  /data/altos/23/ZT/23ZT3TJSGVQDECCUS6SNUFPNCE5C...
#
#                     pagename  \
# 0   ALTO2864623_DDB_FULLTEXT
# 1    ALTO676714_DDB_FULLTEXT
# 2   ALTO5264456_DDB_FULLTEXT
# 3     FILE_0001_DDB_FULLTEXT
# 4  ALTO10636965_DDB_FULLTEXT
#
#                                    preview_reference  \
# 0  https://api.deutsche-digitale-bibliothek.de/bi...
# 1  https://api.deutsche-digitale-bibliothek.de/bi...
# 2  https://api.deutsche-digitale-bibliothek.de/bi...
# 3  https://api.deutsche-digitale-bibliothek.de/bi...
# 4  https://api.deutsche-digitale-bibliothek.de/bi...
#
#                                       processed_text  \
# 0  ur ein  veröfsentlicht eine   n kreizern verse...
# 1  samstag  den   februar  neue sag die dürener b...
# 2  die  lippische landes  zeitung  erscheint mit ...
# 3  enblatt für nationale bezugspreis er durch trä...
# 4  dre hseder in sonden wiosen den dep großangrif...
#
#                                        context_small  similarity
# 0  ur ein . veröfsentlicht eine # # n Kreizern ve...    0.375243
# 1  alpolizei und Staatsanwalt schaft in mühselige...    0.230521
# 2   Druck und Verlag der Meyer ' schen Hofbuchdru...    0.294941
# 3  austpfänder darstellen. Und dann beachte man, ...    0.242570
# 4   verlegt . Die deut schen Wehrmachtformationen...    0.229312

# %%
df = df[:4]

# %%
import pandas as pd
import requests
from google.colab import userdata

# API Config
api_url = "https://ki-chat.uni-mainz.de/api"
api_key = userdata.get('UNI-MAINZ')

def call_mainz_api(system_prompt, user_prompt, temperature=0.0, max_tokens=20000):
    """
    Call University of Mainz API with system and user prompts.
    """
    payload = {
        "model": "Qwen3 235B VL",
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "temperature": temperature,
        "max_tokens": max_tokens
    }

    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }

    response = requests.post(
        f"{api_url}/chat/completions",
        headers=headers,
        json=payload
    )

    if response.status_code != 200:
        raise Exception(f"API Error: HTTP {response.status_code} - {response.text}")

    result = response.json()
    return result['choices'][0]['message']['content']


# Process the DataFrame
all_articles = []
for index, row in df.iterrows():
    try:
        # Make API call
        content = call_mainz_api(
            system_prompt="""You are an expert in OCR-Post-Correction""",
            user_prompt=f"""Please correct OCR error in the newspaper texts. If a word is not readable, add a ?. Only correct if certain
Text to analyze:
{row['context_small']}""",
            temperature=0.0,
            max_tokens=20000
        )

        # Process articles
        if content and "Keine Artikel mit dem angegebenen Thema gefunden." not in content:
            new_row = row.to_dict()
            new_row['article_corrected'] = content.strip()
            all_articles.append(new_row)

        print(f"Processed row {index + 1}/{len(df)}")

    except Exception as e:
        print(f"Error processing row {index}: {str(e)}")
        continue

# Create final DataFrame
result_2_df = pd.DataFrame(all_articles)

# Save to Excel
result_2_df.to_excel('test_2.xlsx', index=False)

# Display results
print(f"\nProcessed {len(result_2_df)} articles successfully")
print(result_2_df.head())
# Out:
# Processed row 1/4
# Processed row 2/4
# Processed row 3/4
# Processed row 4/4
#
# Processed 4 articles successfully
#                                              page_id  pagenumber  \
# 0  22IKTI2DCKL6UM6H62FNWHOG4SIHYRPY-ALTO2864623_D...           3
# 1  22O4KEI3WEZ27D2K65VLFDIONOJAZH5L-ALTO676714_DD...          10
# 2  233N6HVY2EZW3FQCMTO6HN3IXSJ2CIJA-ALTO5264456_D...           1
# 3  23D7JNHE332P6XGZZ4WW65TOCLBQDUBE-FILE_0001_DDB...           1
#
#                                          paper_title  \
# 0                    Mayener Volkszeitung. 1876-1919
# 1                            Der neue Tag. 1934-1944
# 2  Lippische Landes-Zeitung : ältestes und weitve...
# 3  Süddeutsche Zeitung : für deutsche Politik und...
#
#                     provider_ddb_id  \
# 0  VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 1  VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 2  4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 3  VNHXUCEEKHOUSYH4NVOUBHJGSRMOGK7J
#
#                                             provider     zdb_id  \
# 0  Universitäts- und Landesbibliothek der Rheinis...  2664084-3
# 1  Universitäts- und Landesbibliothek der Rheinis...  2927784-X
# 2  Westfälische Wilhelms-Universität Münster Univ...  2944740-9
# 3                  Württembergische Landesbibliothek  3135995-4
#
#      publication_date                              place_of_distribution  \
# 0 1914-10-30 12:00:00                                          ['Mayen']
# 1 1938-02-26 12:00:00                                           ['Köln']
# 2 1881-06-20 12:00:00  ['Extertal', 'Horn-Bad Meinberg', 'Barntrup', ...
# 3 1915-02-19 12:00:00                                      ['Stuttgart']
#
#   language                             thumbnail  \
# 0  ['ger']  0fde6f1f-67cc-49a8-9c5a-b8f806e3410a
# 1  ['ger']  fb256fca-9747-4098-b1fc-a5d3b49d6ed7
# 2  ['ger']  151b36f5-1ce2-4676-9940-08260ced980a
# 3  ['ger']  2ea243ce-eb0c-4475-b64f-6ce176709aff
#
#                                         pagefulltext  \
# 0  /data/altos/22/IK/22IKTI2DCKL6UM6H62FNWHOG4SIH...
# 1  /data/altos/22/O4/22O4KEI3WEZ27D2K65VLFDIONOJA...
# 2  /data/altos/23/3N/233N6HVY2EZW3FQCMTO6HN3IXSJ2...
# 3  /data/altos/23/D7/23D7JNHE332P6XGZZ4WW65TOCLBQ...
#
#                    pagename  \
# 0  ALTO2864623_DDB_FULLTEXT
# 1   ALTO676714_DDB_FULLTEXT
# 2  ALTO5264456_DDB_FULLTEXT
# 3    FILE_0001_DDB_FULLTEXT
#
#                                    preview_reference  \
# 0  https://api.deutsche-digitale-bibliothek.de/bi...
# 1  https://api.deutsche-digitale-bibliothek.de/bi...
# 2  https://api.deutsche-digitale-bibliothek.de/bi...
# 3  https://api.deutsche-digitale-bibliothek.de/bi...
#
#                                       processed_text  \
# 0  ur ein  veröfsentlicht eine   n kreizern verse...
# 1  samstag  den   februar  neue sag die dürener b...
# 2  die  lippische landes  zeitung  erscheint mit ...
# 3  enblatt für nationale bezugspreis er durch trä...
#
#                                        context_small  similarity  \
# 0  ur ein . veröfsentlicht eine # # n Kreizern ve...    0.375243
# 1  alpolizei und Staatsanwalt schaft in mühselige...    0.230521
# 2   Druck und Verlag der Meyer ' schen Hofbuchdru...    0.294941
# 3  austpfänder darstellen. Und dann beachte man, ...    0.242570
#
#                                    article_corrected
# 0  Here is the corrected OCR text with only certa...
# 1  Here is the corrected OCR text. I have correct...
# 2  Here is the corrected OCR text. Only certain, ...
# 3  Here is the corrected version of the OCR text....

# %%
result_2_df['article_corrected'][0]
# Out:
# 'Here is the corrected OCR text with only certain, confident corrections applied. Unreadable or ambiguous words are marked with `?`. I have preserved original formatting and line breaks as much as possible.\n\n---\n\nur ein . veröf**f**entlicht eine # # n Kreuzern versenkten glaube daß acht oder Atlantischen , Stillen ber 70 britische , e und russische **B**eschung der deut Invasion . London , Die englische Heeres **g** , daß es vor Fe **s**chlacht kommen verhüten , wer **N**aßnahmen getrofsen . **B**efestigt und dort mi **F**ekixtowner Kreis ist **e**rt worden . **I**en , 26 . Okt . Wie **s**tigt die Türkei , das über die Chri **s**tianität anzuerkennen . Sie zügliche Besehle ge hat auch die inter **n**ationale **M**acht Constantinopel aufge **f**ordert , **d**en Großmächte an der Türkei einzutre **t**en . **D**ie Behörde hatte sich des Pilgerverkehrs **b**eflissen , **v**on Seuchen nach **T**ürkei diesen Dienst ne versehen lassen **h**at auf diesem Gebiet **K**lasse sind während vor dem Feind ver **h**its und neun Leut **n** und sieben Flieger **d**enszeichens . Außer ein