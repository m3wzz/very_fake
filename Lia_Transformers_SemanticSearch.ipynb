# %% [markdown]
# <a href="https://colab.research.google.com/github/m3wzz/very_fake/blob/main/Lia_Transformers_SemanticSearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tranformers and Semantic Search
#
# "Created by Sarah Oberbichler [![ORCID](data:image/svg+xml;base64,...)](https://orcid.org/0000-0002-1031-2759)
#
# *   Semantic search is a search engine technology that interprets the meaning of words and phrases. The results of a semantic search will return content matching the meaning of a query, as opposed to content that literally matches words in the query.
# *   Semantic search uses context clues to determine the meaning of a word across a dataset of millions of examples.
# Semantic search also identifies what other words can be used in similar contexts.

# %%
# !git clone https://github.com/soberbichler/NLP-Course4Humanities_2025.github.io.git
# Out:
# fatal: destination path 'NLP-Course4Humanities_2025.github.io' already exists and is not an empty directory.

# %%
import pandas as pd

# Replace 'your_excel_file.xlsx' with the actual path to your Excel file
df = pd.read_excel('/content/NLP-Course4Humanities_2025.github.io/datasets/newspaper_lesson.xlsx')

# Now you can work with the DataFrame 'df'
df.head()
# Out:
#                                              page_id  pagenumber  \
# 0  22IKTI2DCKL6UM6H62FNWHOG4SIHYRPY-ALTO2864623_D...           3
# 1  22O4KEI3WEZ27D2K65VLFDIONOJAZH5L-ALTO676714_DD...          10
# 2  233N6HVY2EZW3FQCMTO6HN3IXSJ2CIJA-ALTO5264456_D...           1
# 3  23D7JNHE332P6XGZZ4WW65TOCLBQDUBE-FILE_0001_DDB...           1
# 4  23ZT3TJSGVQDECCUS6SNUFPNCE5CEDUI-ALTO10636965_...           2
#
#                                          paper_title  \
# 0                    Mayener Volkszeitung. 1876-1919
# 1                            Der neue Tag. 1934-1944
# 2  Lippische Landes-Zeitung : ältestes und weitve...
# 3  Süddeutsche Zeitung : für deutsche Politik und...
# 4  Wittener Tageblatt : verbunden mit der Annener...
#
#                     provider_ddb_id  \
# 0  VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 1  VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 2  4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 3  VNHXUCEEKHOUSYH4NVOUBHJGSRMOGK7J
# 4  4EV676FQPACNVNHFEJHGKUY55BXC3QMB
#
#                                             provider     zdb_id  \
# 0  Universitäts- und Landesbibliothek der Rheinis...  2664084-3
# 1  Universitäts- und Landesbibliothek der Rheinis...  2927784-X
# 2  Westfälische Wilhelms-Universität Münster Univ...  2944740-9
# 3                  Württembergische Landesbibliothek  3135995-4
# 4  Westfälische Wilhelms-Universität Münster Univ...  3052283-3
#
#      publication_date                              place_of_distribution  \
# 0 1914-10-30 12:00:00                                          ['Mayen']
# 1 1938-02-26 12:00:00                                           ['Köln']
# 2 1881-06-20 12:00:00  ['Extertal', 'Horn-Bad Meinberg', 'Barntrup', ...
# 3 1915-02-19 12:00:00                                      ['Stuttgart']
# 4 1940-10-14 12:00:00                                         ['Witten']
#
#   language                             thumbnail  \
# 0  ['ger']  0fde6f1f-67cc-49a8-9c5a-b8f806e3410a
# 1  ['ger']  fb256fca-9747-4098-b1fc-a5d3b49d6ed7
# 2  ['ger']  151b36f5-1ce2-4676-9940-08260ced980a
# 3  ['ger']  2ea243ce-eb0c-4475-b64f-6ce176709aff
# 4  ['ger']  cf34ec30-f901-4dc5-b195-e577429c885f
#
#                                         pagefulltext  \
# 0  /data/altos/22/IK/22IKTI2DCKL6UM6H62FNWHOG4SIH...
# 1  /data/altos/22/O4/22O4KEI3WEZ27D2K65VLFDIONOJA...
# 2  /data/altos/23/3N/233N6HVY2EZW3FQCMTO6HN3IXSJ2...
# 3  /data/altos/23/D7/23D7JNHE332P6XGZZ4WW65TOCLBQ...
# 4  /data/altos/23/ZT/23ZT3TJSGVQDECCUS6SNUFPNCE5C...
#
#                     pagename  \
# 0   ALTO2864623_DDB_FULLTEXT
# 1    ALTO676714_DDB_FULLTEXT
# 2   ALTO5264456_DDB_FULLTEXT
# 3     FILE_0001_DDB_FULLTEXT
# 4  ALTO10636965_DDB_FULLTEXT
#
#                                    preview_reference  \
# 0  https://api.deutsche-digitale-bibliothek.de/bi...
# 1  https://api.deutsche-digitale-bibliothek.de/bi...
# 2  https://api.deutsche-digitale-bibliothek.de/bi...
# 3  https://api.deutsche-digitale-bibliothek.de/bi...
# 4  https://api.deutsche-digitale-bibliothek.de/bi...
#
#                                    plainpagefulltext
# 0  ur ein . veröfsentlicht eine # # n Kreizern ve...
# 1  Samstag , den 26 . Februar 1938 Neue sag Die D...
# 2  Die „ Lippische Landes = Zeitung " erscheint m...
# 3  enblatt für nationale Bezugspreis er durch Trä...
# 4  Dre hseder in Sonden Wiosen den Dep Großangrif...

# %%
# @markdown #### Installing the Sentence Tranfromers from HuggingFace
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.1.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.57.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.9.0+cu126)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.11.12)

# %% [markdown]
# #Using Transformers to find similar words
#
# Findig similar words is one of the most basic tasks for semantic search. While still operating on keywords, transformer models help us identify words with similar or related meanings, allowing us to broaden the scope of traditional keyword searches. This approach helps find relevant content even when exact keyword matches aren't present, by including semantically related terms in the search process.
#
# This code below implements a semantic word similarity search using the multilingual LaBSE transformer model (https://huggingface.co/sentence-transformers/LaBSE), where vector embeddings are generated dynamically based on context, unlike static word embeddings from older methods like Word2Vec. It processes a text corpus by converting all text to lowercase and removing special characters.
# The core functionality uses the transformer model to convert words into vector embeddings, then calculates cosine similarity between a target word and all other filtered words from the corpus.
#
# Cosine similarity measures the similarity between two vectors by calculating the cosine of the angle between them.

# %%
df = df[:200]

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import re
from sentence_transformers import SentenceTransformer
from collections import Counter

def preprocess_text(text):
    if pd.isna(text):
        return ""
    text = str(text).lower()
    text = re.sub(r'[^a-zäöüß\s]', '', text)
    return text

def get_unique_words(text):
    words = text.split()
    return list(set(words))

def find_similar_words(df, target_word, model, top_n=40):
    # Preprocess the text
    df['processed_text'] = df['plainpagefulltext'].apply(preprocess_text)

    # Get unique words from all texts
    all_words = []
    for text in df['processed_text']:
        all_words.extend(get_unique_words(text))

    # Get unique words and their frequencies
    word_freq = Counter(all_words)
    unique_words = list(word_freq.keys())

    print(f"Number of unique words: {len(unique_words)}")

    # Encode the target word and unique words
    target_embedding = model.encode([target_word])
    word_embeddings = model.encode(unique_words)

    # Calculate similarities
    similarities = cosine_similarity(target_embedding, word_embeddings)[0]

    # Create a DataFrame with words and their similarities
    word_sim_df = pd.DataFrame({
        'word': unique_words,
        'similarity': similarities
    })

    # Sort by similarity and get top N results
    top_similar = word_sim_df.sort_values('similarity', ascending=False).head(top_n)

    return top_similar

# Load the pre-trained multilingual model
print("Loading the sentence transformer model...")
model = SentenceTransformer('sentence-transformers/LaBSE')
print("Model loaded successfully.")

target_word = "Lügenpresse"

print(f"\nFinding words similar to '{target_word}'...")
similar_words = find_similar_words(df, target_word, model)

print("\nMost similar words:")
print(similar_words)
# Out:
# Loading the sentence transformer model...
# modules.json:   0%|          | 0.00/461 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/804 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/397 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/114 [00:00<?, ?B/s]
# 2_Dense/model.safetensors:   0%|          | 0.00/2.36M [00:00<?, ?B/s]
# Model loaded successfully.
#
# Finding words similar to 'Lügenpresse'...
# Number of unique words: 79215
#
# Most similar words:
#                             word  similarity
# 376                  lügenpresse    0.913250
# 5035                   lügenpree    0.743877
# 44278              lügenpeitsche    0.698087
# 12773                 presseluge    0.686018
# 28337               lügenfeldzug    0.678315
# 69874               lügenseldzug    0.677544
# 11671                  lügenflut    0.671023
# 33524                presselüige    0.668292
# 50786                  presselüg    0.667829
# 66753                 presselüqe    0.663663
# 11990                   lusdruck    0.662479
# 4955                  presselüge    0.660740
# 64538                  lügenbund    0.660458
# 57289                judenpresse    0.657082
# 21947                 lügenkuche    0.655404
# 4486                pressegisegt    0.655018
# 63527               pressezensur    0.654807
# 53828               pressefolter    0.654570
# 11612                presselügen    0.653290
# 12142            lügenpropaganda    0.651793
# 16864                 lügensuppe    0.643209
# 52220            lügenprovaganda    0.638710
# 11874             pressevertrete    0.637707
# 11735                 lügenhetze    0.636628
# 11274               pressewesens    0.632498
# 66745                  pressewge    0.631378
# 69946                  lügenpost    0.630079
# 40589  reichsverbandslügenpresse    0.627100
# 31745                pressewesen    0.625215
# 66769                 presseküge    0.624988
# 11573               pressepraxis    0.620204
# 64889               somjeipresse    0.616326
# 23910                tagespresse    0.614011
# 4594                 pressehetze    0.613401
# 4739                lügenspiegel    0.612362
# 28562                  lügennetz    0.611422
# 11811                 lügensucht    0.604173
# 58431                pressemeute    0.602394
# 69919               pressebureau    0.601885
# 11265             lügennachricht    0.601746

# %% [markdown]
# # Keyword Intepended Search
#
# Unlike traditional keyword search, which would only find exact matches of words like "earthquake" or "reconstruction," semantic search understands the conceptual meaning of the entire query. For example, when searching for "reconstruction after earthquake," the system understands this as a concept involving disaster recovery, rebuilding efforts, community restoration, and infrastructure repair. This means it can identify relevant content that discusses these themes using different terminology - perhaps an article about "community revival following seismic damage" or "rebuilding homes in disaster-struck areas." The search works by transforming both the query and the searchable content into mathematical representations (vectors) that capture their meaning in a multidimensional space, where similar concepts cluster together regardless of the specific words used to express them. This allows for a more intuitive and human-like understanding of language, capturing context, synonyms, related concepts, and even cross-language connections, ultimately providing more relevant and comprehensive search results that align with the user's actual information needs.

# %% [markdown]
# ###First, let's create a context window around the words in the similar_words list

# %% [markdown]
# The code below implements a semantic search functionality using a multilingual transformer model to find relevant articles for a specific query in a dataset. It first processes and cleans the input data, then uses the SBERT (Sentence-BERT) model 'paraphrase-multilingual-MiniLM-L12-v2' to convert both the search query and all articles into numerical vectors (embeddings) that capture their semantic meaning. Using cosine similarity, it then calculates how closely each article matches the search query, assigns similarity scores, and filters out articles with scores below 0.6. The results are sorted by similarity score in descending order, and the code outputs the top 10 most relevant articles, displaying their similarity scores, titles, and the first 600 characters of their content, making it easy to identify articles that are semantically related to the reconstruction after earthquakes theme, even if they don't contain the exact search terms.

# %%
def extract_context(keywords, text, tokens_before, tokens_after):
    # Ensure text is a string before processing
    if pd.isna(text):
        return ""
    text = str(text)

    # transform text to lower letters
    lower_text = text.lower()

    # find all keyword positions (case-insensitive)
    keyword_positions = []
    for keyword in keywords:
        keyword_start = lower_text.find(keyword)
        while keyword_start != -1:
            keyword_positions.append(keyword_start)
            keyword_start = lower_text.find(keyword, keyword_start + len(keyword))

    if not keyword_positions:
        return "Keywords not found in text."

    # Determine start and end of context window
    first_occurrence = min(keyword_positions)
    last_occurrence = max(keyword_positions)

    start_index = max(0, first_occurrence - tokens_before)
    end_index = min(len(text), last_occurrence + tokens_after)

    # Extract context from original text
    context = text[start_index:end_index]

    return context

# keywords
keywords = similar_words

# append context column
df['context_small'] = [extract_context(keywords, row['plainpagefulltext'], 500, 1000) for _, row in df.iterrows()]

# %%
df['context_small'][0]
# Out:
# 'ur ein . veröfsentlicht eine # # n Kreizern versenkten glaube daß acht oder Atlantischen , Stillen ber 70 britische , e und russische chung der deut Invasion . London , Die englische Heeres g , daß es vor Fe eschlacht kommen verhüten , wer Naßnahmen getrofsen . efestigt und dort mi Fekixtowner Kreis ist ert worden . ien , 26 . Oll . Wie stigt die Türkei , das über die Chri anzuerkennen . Sie zügliche Besehle ge hat auch die inter mstantinopel aufge inen Großmächte an der Türkei einzutre behörde hatte sich des Pilgerverkehrs ig von Seuchen nach irkei diesen Dienst ne versehen lassen h auf diesem Gebiet klasse sind während vor dem Feind ver its und neun Leut und sieben Flieger denszeichens . Außer einem Vizefeldwebel , mann und Verwal inopel berichtet , auf habe die Pforte er is Wochen lang ge chafter habe erklärt , dann den Ankerplatz n die Dar danellen s im Schwarzen anöver entstanden . jarfe Schüsse gegen ind machten nach iöver . cant " wird von zu ahl der Internier irden , bis zum 21 . ren 300 Offiziere . 000 Mann an der * , und gestern und ntransporte durch in die Zahl der in 50 000 schätzen urnal “ ergibt sich , igland begeben ha ilden zu helfen . mmandos . die militärisch für ieder . zu der Frage der Versuche , die vor nordamerikanischen ntimeter = Geschützen i mit 350 Kilo on 18 Kilometern Fles , daß auf er erzielt wor dischen Feldheeres d des belgischen einer amerikani ind dazu gehörige in Dollar gekauft . der England vor „ Rußkija Wjedo ßter Ruhe davon , ger danern könne . er Krieg koste sie t vom Schusse , reist keine Fami chweig hat ein in einer Klasse ndes für Ver as Ordenszeichen eifen eingefaßten getragen . Es cht zuruckgegeben in Lissabon eine Bureau nittelbar an der in Dorfgemeinde in dem etwa dergebrannt . eilt nun einige , über mit . Gleich der Direktor der r Stadt Braun e der städtischen jedoch ab , weil die Stadtgrenze eister war nicht tiger erschien ts des Brandes mit derselben nister Boden idtischen Feuer so sind infolge Zentner Brot eit ! n . e Unteroffizier Inf . = Regt . 39 , wurde wegen m „ Eisernen ericht der stein . Unter orsätzlich und haben , stand Korscheid vor m Jahre 1882 glücklich ; im ind begab sich August dieses Jahres hielt er urr a . Main auf und kaufte sich dort Loiver , sowie eine Anzahl scharfe Patronen . 50 . August reiste er von Frankfurt nach Cob enz , wo er in einer Wirtschaft übemachtetennd am folgenden Morgen suhr er dann nach seiner Hei mat Morshausen . Hier begab er sich zunächst in das Haus seines Bruders , wo er sich mehrer Tage auf hielt . Am5 . Septembertraf er auf der Straße seine Frau und nach einer Aussprache zog er mit ihr wieder zusammen . Am Vormittage des 10 . Septbr . scheint es nun in der Wohnung zwischen den Ehe leuten zu einer Auseinandersetzung gekommen zu sein . Wie sich der Vorfall im einzelnen ab gespielt hat , konnte nicht genau festgestellt werden , weil die Ehefrau in der Verhandlung ihr Zeugnis verwei gete . Der Angetlagte hatte aber 3 Schüsse auf seine Frau abgegeben , von denen einer die Frau in den Arm traf Der Angeklagte bestritt entschieden die Absicht gehabt zu haben , seine Frau zu töten . Den Revolver will er nur deshalb gekauft haben , weil er Angst vor seinen Verwandten gehabt hätte . Nach längerer Verhandlung erkannte das Kriegs gericht dahin , daß durch die Beweisaufnahme nicht festgestellt worden sei , daß der Angeklagte die Tat mit Ueberlegung ausgeführt habe . Er wurde daher nur wegen unberechtigten Waffentragens , ohne Anrechnung der Untersuchungshaft , zu 2 Monaten Gefängnis verurteilt . Wegen der Be schuldigung , seine Ehefrau vorsetzlich , jedoch nicht mit Ueberlegung zu töten versucht zu haben , wurde der Beschuldigte vor das Schwurgericht verwiesen . Köln , 29 . Okt . Wie französische „ Da men “ , deutsche Gefangene behandeln . Wie unsre in Gefangenschaft geratenen Soldaten in Frankreich von den Damen behandelt werden , berichtet ein aus der Gefangenschaft zurückgekehrter Sanitäter dem Westf . Merkur . Im Gefangenen lager erhielten sie ...

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import torch

# Load the transformer model
model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')

# Query phrase for semantic search
query = "Ausländische Presse und Lügenpresse im Ausland"

# Preprocess DataFrame: drop rows where 'context_small' is NaN or not a string
if 'context_small' not in df.columns:
    raise ValueError("The column 'context_small' is missing in the DataFrame.")

# Drop rows with missing values in 'extracted_article_clean'
df = df.dropna(subset=['context_small'])

# Ensure all entries in 'extracted_article_clean' are strings
df.loc[:, 'context_small'] = df['context_small'].astype(str)

# Encode the 'extracted_article_clean' column from the DataFrame
article_embeddings = model.encode(df['context_small'].tolist(), convert_to_tensor=True)

# Encode the query
query_embedding = model.encode(query, convert_to_tensor=True)

# Calculate cosine similarity between query and each article
similarities = util.pytorch_cos_sim(query_embedding, article_embeddings)[0]

# Add similarity scores to the DataFrame
df = df.copy()  # Avoid potential chained assignment warnings
df.loc[:, 'similarity'] = similarities.cpu().numpy()

# Filter articles with similarity score > 0.6
high_similarity_df = df[df['similarity'] > 0.6].copy()

# Sort by similarity in descending order
high_similarity_df = high_similarity_df.sort_values('similarity', ascending=False)

# Print the number of articles found with similarity > 0.5
print(f"\nFound {len(high_similarity_df)} context windows with similarity score > 0.6")

# Print the top 10 highest similarity scores as examples
print("\nTop 10 highest similarity scores:")
top_10_examples = high_similarity_df.head(10)
for _, row in top_10_examples.iterrows():
    print(f"\nSimilarity Score: {row['similarity']:.4f}")
    print(f"Title: {row['paper_title']}")
    print(f"First 1000 characters of article: {row['context_small'][:1000]}...")

# Save the filtered DataFrame to a new variable
filtered_df = high_similarity_df

print(f"\nShape of filtered DataFrame: {filtered_df.shape}")
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
#
#
# Similarity Score: 0.6058
# Title: Münsterländische Volkszeitung : allgemeiner Anzeiger für Stadt u. Amt Rheine : Zeno-Zeitung ; [...] ; Rheiner Volksblatt
# First 1000 characters of article: ein dauerndes Moment der Unruhe und Beunruhi gung gewesen ist und sein mußte . Wir wissen heute , daß die Presse von London und Paris in Ge meinschaft mit den amtlichen Vertretern wieder ein mal das „ seelische Gleichgewicht “ verlieren werden , weil dem Gesetz der Gerechtigkeit zum Sieg ver holfen worden ist , das sie selbst nicht nur mißachtet , sondern unter politischer Berechnung gebeugt , ver achtet und mit Füßen getreten haben . Die Ruhe und die Sicherheit unserer Halt : die eine Haltung des ganzen deutschen Volkes ist , werden sie nicht im mindesten in Erschütterung brin eie Zie üchdeehtis auf unserer Seite . Der Wel , die sich baran erinnern muß , daß das britische Imperium in seiner Entstehung nichts anderes ist als ein einziger großer Gewaltakt über fremdes Volkstum , wird sich nicht täuschen lässen . Sie wird erkennen , daß Deutschlands Weg in Europa nur der Weg der Wiederherstellung jenes unveräußerlichen Rechtes ist , das wir durch die Zusammenge hörigkeit des Blutes und d...
#
# Similarity Score: 0.6019
# Title: Kölnische Zeitung. 1803-1945
# First 1000 characters of article: men sollte , sich als solcher auf demselben zu Wver . Dom östlichen Schauplatz . Eine russische Schandtat . WTB Wien , 30 . Juni . ( Telegr . ) Aus dem Kriegspresse quartier wird gemeldet : Die Lügenpresse des Vierverbandes , die immer bereit ist , erfundene Erfolge unserer Gegner zu schildern , kann auch beharrlich schweigen , wenn es sich um verbrecherische Vorgänge handelt , die vor Kriegs beginn noch völkerrechtswidrig waren . Immer wieder wurden russische Greuel abgeleugnet , offenkundig gewordene verbrecherische Handlungen solcher Soldateska aber beschönigt . Nun wird wieder ein Fall bekannt , der in seiner Scheußlichkeit vielleicht einzig dasteht und der weiten öffentlichkeit zur Kenntnis kommen muß . Anläßlich des Gefechts bei Rarancze am 10 . Juni nördlich Tschernowitz blieben zwei schwer ver wundete österreichische Soldaten am Felde liegen . Die Raranczer Bauernbevölkerung nahm sich der Verwundeten an und brachte sie in eine Scheune . Die Russen fanden die Schwerverwundeten ,...
#
# Shape of filtered DataFrame: (8, 17)

# %%
filtered_df
# Out:
#                                                page_id  pagenumber  \
# 38   2HAMXXMTL4AF7YXSCRMG57F2U3CME5TV-ALTO1158203_D...           1
# 101  3DJ3YQU5Z55X2EANJBGOFO4IARF7FZCL-ocr_1_DDB_FUL...           1
# 32   2F7H4QGGAZBBOP2VN6SREXSP5H6SJ6B4-uuid-d95cdd63...           6
# 59   2PGNKXI4VARBXPFY7ISXZBMI24VAJM6E-ALTO6689525_D...           3
# 155  46KLQ4OEB4IMXOGBRGNW44NAFZU364IC-ALTO1066142_D...           6
# 71   2TS2IX7YES3NRJTGVH3O5B43S7STISEP-ALTO843489_DD...           2
# 31   2EVWG7RM6A23DDEN2GQR3N4Q2V54QX6C-ALTO801216_DD...           2
# 139  3VGIM2NVXPF776YKLS4O5TQTYANXQWSE-ALTO9193918_D...           8
#
#                                            paper_title  \
# 38                       Dortmunder Zeitung. 1874-1939
# 101                                           Vorwärts
# 32   Eibenstocker Tageblatt : Anzeiger für den Amts...
# 59   Rhein- und Ruhrzeitung : Tageszeitung für das ...
# 155  Jeversches Wochenblatt : Friesisches Tageblatt...
# 71                   Bünder Generalanzeiger. 1938-1938
# 31   Münsterländische Volkszeitung : allgemeiner An...
# 139                       Kölnische Zeitung. 1803-1945
#
#                       provider_ddb_id  \
# 38   4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 101  CZTZO4SBNHW34JVKYRWW67725WWGLZA5
# 32   265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 59   VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
# 155  56EXT7QNQMRDQY4ZZWQGOLXGR3IN3C4F
# 71   4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 31   4EV676FQPACNVNHFEJHGKUY55BXC3QMB
# 139  VKNQFFAKOR4XZWJJKUX3NGYSZ3QZAXCW
#
#                                               provider     zdb_id  \
# 38   Westfälische Wilhelms-Universität Münster Univ...  2941861-6
# 101            Bibliothek der Friedrich-Ebert-Stiftung  2814128-3
# 32   Sächsische Landesbibliothek - Staats- und Univ...  2814605-0
# 59   Universitäts- und Landesbibliothek der Rheinis...  2971362-6
# 155                         Landesbibliothek Oldenburg   824611-7
# 71   Westfälische Wilhelms-Universität Münster Univ...  2940954-8
# 31   Westfälische Wilhelms-Universität Münster Univ...  2935918-1
# 139  Universitäts- und Landesbibliothek der Rheinis...  2719361-5
#
#        publication_date                              place_of_distribution  \
# 38  1938-09-08 12:00:00                                       ['Dortmund']
# 101 1909-08-12 12:00:00                                         ['Berlin']
# 32  1938-09-09 12:00:00  ['Eibenstock', 'Eibenstock-Blauenthal', 'Carls...
# 59  1938-09-09 12:00:00  ['Duisburg', 'Mülheim an der Ruhr', 'Ruhrort',...
# 155 1938-09-09 12:00:00                                          ['Jever']
# 71  1938-02-28 12:00:00             ['Bünde', 'Bünde-Ennigloh', 'Herford']
# 31  1939-03-23 12:00:00                                         ['Rheine']
# 139 1915-07-01 12:00:00          ['Köln', 'Kleve (Kreis Kleve)', 'Jülich']
#
#     language                             thumbnail  \
# 38   ['ger']  ca65ac68-deb1-48b6-be18-b47443079703
# 101  ['ger']  f8d2752a-8a34-4b46-a5fa-7ed7fc7bbbf0
# 32   ['ger']  9325cab8-ce84-4060-8de7-487c547feea7
# 59   ['ger']  9386de61-884c-4d7e-bfc1-09c5b56ba3e1
# 155  ['ger']  260db11a-2554-4b9d-b31f-44938d38301f
# 71   ['ger']  43c3e6b2-4869-4d0f-a8e5-8ee866b9b5a9
# 31   ['ger']  a2134a62-f910-440c-88b1-ef50344fd987
# 139  ['ger']  6c762a51-d1ab-4ee2-9cf2-25f5bdd2218a
#
#                                           pagefulltext  \
# 38   /data/altos/2H/AM/2HAMXXMTL4AF7YXSCRMG57F2U3CM...
# 101  /data/altos/3D/J3/3DJ3YQU5Z55X2EANJBGOFO4IARF7...
# 32   /data/altos/2F/7H/2F7H4QGGAZBBOP2VN6SREXSP5H6S...
# 59   /data/altos/2P/GN/2PGNKXI4VARBXPFY7ISXZBMI24VA...
# 155  /data/altos/46/KL/46KLQ4OEB4IMXOGBRGNW44NAFZU3...
# 71   /data/altos/2T/S2/2TS2IX7YES3NRJTGVH3O5B43S7ST...
# 31   /data/altos/2E/VW/2EVWG7RM6A23DDEN2GQR3N4Q2V54...
# 139  /data/altos/3V/GI/3VGIM2NVXPF776YKLS4O5TQTYANX...
#
#                                               pagename  \
# 38                            ALTO1158203_DDB_FULLTEXT
# 101                                 ocr_1_DDB_FULLTEXT
# 32   uuid-d95cdd63-9533-490b-aa0e-0d88fc9645f1_DDB_...
# 59                            ALTO6689525_DDB_FULLTEXT
# 155                           ALTO1066142_DDB_FULLTEXT
# 71                             ALTO843489_DDB_FULLTEXT
# 31                             ALTO801216_DDB_FULLTEXT
# 139                           ALTO9193918_DDB_FULLTEXT
#
#                                      preview_reference  \
# 38   https://api.deutsche-digitale-bibliothek.de/bi...
# 101  https://api.deutsche-digitale-bibliothek.de/bi...
# 32   https://api.deutsche-digitale-bibliothek.de/bi...
# 59   https://api.deutsche-digitale-bibliothek.de/bi...
# 155  https://api.deutsche-digitale-bibliothek.de/bi...
# 71   https://api.deutsche-digitale-bibliothek.de/bi...
# 31   https://api.deutsche-digitale-bibliothek.de/bi...
# 139  https://api.deutsche-digitale-bibliothek.de/bi...
#
#                                      plainpagefulltext  \
# 38   8 . BEPTBR . 1938 kusmeister sie europäischen ...
# 101  Ur. 186. BbenncmenfS'Bcdlngtifigen: Wonncnicnt...
# 32   Dr. Dietrich erwähnte weiter seine vor den Mit...
# 59   Rhein - und Ruhrzeitung Nr . 246 Die „ interes...
# 155  Äie unheimliche Macht öer zersetzeaöeu Kresse!...
# 71   AL S3 45 54 Au 83 A3 Chautemps in alten Bahnen...
# 31   ein dauerndes Moment der Unruhe und Beunruhi g...
# 139  Donnerstag , 1 . Juli Kölnische Zeitung e Mitt...
#
#                                         processed_text  \
# 38     beptbr   kusmeister sie europäischen leicht ...
# 101  ur  bbenncmenfsbcdlngtifigen wonncnicnts  prci...
# 32   dr dietrich erwähnte weiter seine vor den mitg...
# 59   rhein  und ruhrzeitung nr   die  interessante ...
# 155  äie unheimliche macht öer zersetzeaöeu kresse ...
# 71   al s   au  a chautemps in alten bahnen ministe...
# 31   ein dauerndes moment der unruhe und beunruhi g...
# 139  donnerstag    juli kölnische zeitung e mittags...
#
#                                          context_small  similarity
# 38   hrte sen , welche die n Jahren ein r Presse . ...    0.694674
# 101  ne Haut angehen, selbständig zu denken beginnt...    0.673503
# 32   r Demokratie aus die deutschen Anklagen und Vo...    0.642052
# 59   rvermittlungswerkzeug der Welt . Ich glaube , ...    0.635015
# 155   zersetzeaöeu Kresse! Mrnberg . Auf dem Partei...    0.609786
# 71    Kammeraussprache eine sehr geteilte Auf Rh de...    0.606383
# 31   ein dauerndes Moment der Unruhe und Beunruhi g...    0.605805
# 139  men sollte , sich als solcher auf demselben zu...    0.601903
